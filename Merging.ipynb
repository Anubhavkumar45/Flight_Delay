# %%
import numpy as np
import pandas as pd
import os

# %%
folderPath = "C:/Users/Anubhav/Documents/Projects/Flight Data/cleaneddata"
os.chdir(folderPath)
fdata = pd.DataFrame()
for filename in os.listdir(os.getcwd()):#Reads all data files from above location
    temp = pd.read_csv(filename,index_col=0)
    df1 = temp.sample(frac =0.1)
    fdata = fdata.append(df1)

# %%
fdata.shape
# Out:
# (266291, 50)

# %%
folderPath = "C:/Users/Anubhav/Documents/Projects/Flight Data"
os.chdir(folderPath)#Setting working directory

# %%
fdata.head(5)
# Out:
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 311064  2019        4     12          22          7    20191222
# 234679  2019        4     12          13          5    20191213
# 262972  2020        1      1          18          6    20200118
# 358219  2019        4     12          30          1    20191230
# 188590  2019        4     12          31          2    20191231
#
#        Reporting_Airline  DOT_ID_Reporting_Airline  \
# 311064                AA                     19805
# 234679                OO                     20304
# 262972                AA                     19805
# 358219                YV                     20378
# 188590                UA                     19977
#
#        IATA_CODE_Reporting_Airline Tail_Number  ...  ArrivalDelayGroups  \
# 311064                          AA      N722US  ...                 0.0
# 234679                          OO      N430SW  ...                12.0
# 262972                          AA      N337PJ  ...                 5.0
# 358219                          YV      N907FJ  ...                 4.0
# 188590                          UA      N75426  ...                -2.0
#
#         ArrTimeBlk  Cancelled  Diverted CRSElapsedTime ActualElapsedTime  \
# 311064   1900-1959        0.0       0.0          103.0             116.0
# 234679   0700-0759        0.0       0.0           82.0              65.0
# 262972   0800-0859        0.0       0.0          142.0             219.0
# 358219   1800-1859        0.0       0.0           92.0              87.0
# 188590   1800-1859        0.0       0.0          147.0             128.0
#
#        AirTime  Flights Distance  DistanceGroup
# 311064    85.0      1.0    511.0              3
# 234679    45.0      1.0    243.0              1
# 262972    88.0      1.0    624.0              3
# 358219    68.0      1.0    369.0              2
# 188590   107.0      1.0    775.0              4
#
# [5 rows x 50 columns]

# %%
fdata.to_csv('finalcleaned.csv',index=False)
